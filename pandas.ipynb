# %% [markdown]
# ## Read a csv file using for loop

# %%
x = []
for line in open('data/data_2d.csv'):
    line = line.split(',')
    line = list(map(float, line))
    x.append(line)
x
# Out:
# [[17.9302012052, 94.5205919533, 320.259529602],
#  [97.1446971852, 69.5932819844, 404.634471526],
#  [81.7759007845, 5.73764809688, 181.485107741],
#  [55.8543424175, 70.3259016768, 321.773638018],
#  [49.3665499855, 75.1140401571, 322.465485583],
#  [3.19270246506, 29.2562988631, 94.6188108954],
#  [49.2007840582, 86.1444385075, 356.348092747],
#  [21.882803904, 46.8415051959, 181.653769226],
#  [79.5098627219, 87.397355535, 423.557743194],
#  [88.1538874975, 65.2056419279, 369.229245443],
#  [60.7438543399, 99.9576339008, 427.605803661],
#  [67.4155819451, 50.3683096094, 292.471821553],
#  [48.3181157719, 99.1289531425, 395.529811407],
#  [28.8299719729, 87.1849488537, 319.031348455],
#  [43.853742664, 64.4736390798, 287.4281441],
#  [25.3136940868, 83.5452942552, 292.768908839],
#  [10.807726675, 45.6955685904, 159.663307674],
#  [98.365745882, 82.6973935253, 438.798963866],
#  [29.1469099692, 66.3651067611, 250.986309034],
#  [65.1003018959, 33.3538834975, 231.711507921],
# ...

# %%
import numpy as np

# %%
num_array = np.array(x)

# %%
num_array.shape
# Out:
# (100, 3)

# %%
import pandas as pd

# %%
# data frame
df = pd.read_csv("data/data_2d.csv", header=None)

# %%
df
# Out:
#             0          1           2
# 0   17.930201  94.520592  320.259530
# 1   97.144697  69.593282  404.634472
# 2   81.775901   5.737648  181.485108
# 3   55.854342  70.325902  321.773638
# 4   49.366550  75.114040  322.465486
# 5    3.192702  29.256299   94.618811
# 6   49.200784  86.144439  356.348093
# 7   21.882804  46.841505  181.653769
# 8   79.509863  87.397356  423.557743
# 9   88.153887  65.205642  369.229245
# 10  60.743854  99.957634  427.605804
# 11  67.415582  50.368310  292.471822
# 12  48.318116  99.128953  395.529811
# 13  28.829972  87.184949  319.031348
# 14  43.853743  64.473639  287.428144
# 15  25.313694  83.545294  292.768909
# 16  10.807727  45.695569  159.663308
# 17  98.365746  82.697394  438.798964
# 18  29.146910  66.365107  250.986309
# 19  65.100302  33.353883  231.711508
# 20  24.644113  39.540053  163.398161
# 21  37.559805   1.345728   83.480155
# 22  88.164506  95.153663  466.265806
# 23  13.834621  25.494048  100.886430
# ...

# %%
df.shape
# Out:
# (100, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# 0    100 non-null float64
# 1    100 non-null float64
# 2    100 non-null float64
# dtypes: float64(3)
# memory usage: 2.4 KB

# %%
df.describe()
# Out:
#                 0           1           2
# count  100.000000  100.000000  100.000000
# mean    47.977794   56.271284  265.334490
# std     29.776540   30.218386  106.375043
# min      1.382983    0.127891   43.915692
# 25%     21.695463   32.510100  177.063748
# 50%     48.401451   60.979979  268.342711
# 75%     72.460241   82.909369  353.787315
# max     98.998373   99.957634  466.265806

# %%
df.head()
# Out:
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465486

# %%
df.head(10)
# Out:
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465
# 24  64.410844  365.641048
# 25  68.925992  426.140015
# 26  39.488442  235.532389
# 27  52.463178  283.291640
# 28  48.484787  298.581440
# 29   8.062088  309.234109
# ..        ...         ...
# 70  30.187692   89.539008
# 71  11.788418  181.550683
# 72  18.292424  224.773383
# ...

# %%
# run the first 5 rows from columns 0 and 2
df[[0,2]].head()
# Out:
#            0           2
# 0  17.930201  320.259530
# 1  97.144697  404.634472
# 2  81.775901  181.485108
# 3  55.854342  321.773638
# 4  49.366550  322.465486

# %%
# to access a specific cell, convert df into numpy array
m = df.as_matrix()
m[0,0]
# Out:
# 17.930201205199999

# %%
# Data frame is for 2d objects
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Series is for 1d object
type(df[0].head(1))
# Out:
# pandas.core.series.Series

# %%
# find all rows where column 0 is greater than 90
df[df[0] > 90]
# Out:
#             0          1           2
# 1   97.144697  69.593282  404.634472
# 17  98.365746  82.697394  438.798964
# 35  95.368610  47.295507  336.126739
# 41  93.990404   0.127891  196.716167
# 43  98.998373  60.231266  384.381345
# 46  97.834141   2.023908  201.293598
# 52  93.400802  18.075246  235.472382
# 66  96.215656  25.834283  280.617044
# 73  96.712668   9.029102  219.567094
# 79  94.493058  88.417197  447.132704
# 89  97.646950   8.147625  219.160280

# %%
df[0]>0
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
#       ...
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True
# 81    True
# 82    True
# 83    True
# 84    True
# 85    True
# 86    True
# 87    True
# 88    True
# 89    True
# 90    True
# 91    True
# 92    True
# 93    True
# 94    True
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: 0, Length: 100, dtype: bool

# %%
# !ls data/*csv
# Out:
# data/data_2d.csv			   data/table1.csv
# data/international-airline-passengers.csv  data/table2.csv

# %%
df = pd.read_csv("data/international-airline-passengers.csv", engine='python', skipfooter=3)

# %%
df.head()
# Out:
#      Month  \
# 0  1949-01
# 1  1949-02
# 2  1949-03
# 3  1949-04
# 4  1949-05
#
#    International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                                112
# 1                                                118
# 2                                                132
# 3                                                129
# 4                                                121

# %%
# to find the name of the columns
df.columns
# Out:
# Index(['Month', 'International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60'], dtype='object')

# %%
# Rename columns to month and passengers
df.columns=('month','passengers')

# %%
df['month'].head()
# Out:
# 0    1949-01
# 1    1949-02
# 2    1949-03
# 3    1949-04
# 4    1949-05
# Name: month, dtype: object

# %%
# accessing with column names
df.month.head()
# Out:
# 0    1949-01
# 1    1949-02
# 2    1949-03
# 3    1949-04
# 4    1949-05
# Name: month, dtype: object

# %%
# Adding column named ones and assigning a value 1

df['ones'] = 1
df.ones.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: ones, dtype: int64

# %%
# Create a new column with datetime object
from datetime import datetime
df ['dt'] = df.apply(lambda row: datetime.strptime(row['month'],"%Y-%m"), axis=1)

# %%
df.head()
# Out:
#      month  passengers  ones         dt
# 0  1949-01         112     1 1949-01-01
# 1  1949-02         118     1 1949-02-01
# 2  1949-03         132     1 1949-03-01
# 3  1949-04         129     1 1949-04-01
# 4  1949-05         121     1 1949-05-01

# %%
# Join of two tables
t1 = pd.read_csv("data/table1.csv")
t2 = pd.read_csv("data/table2.csv")

# %%
t1
# Out:
#    user_id            email  age
# 0        1  alice@gmail.com   20
# 1        2    bob@gmail.com   25
# 2        3  carol@gmail.com   30

# %%
t2
# Out:
#     user_id  ad_id  click
# 0         1      1      1
# 1         1      2      0
# 2         1      5      0
# 3         2      3      0
# 4         2      4      1
# 5         2      1      0
# 6         3      2      0
# 7         3      1      0
# 8         3      3      0
# 9         3      4      0
# 10        3      5      1

# %%
m = pd.merge(t1,t2, on='user_id')

# %%
m
# Out:
#     user_id            email  age  ad_id  click
# 0         1  alice@gmail.com   20      1      1
# 1         1  alice@gmail.com   20      2      0
# 2         1  alice@gmail.com   20      5      0
# 3         2    bob@gmail.com   25      3      0
# 4         2    bob@gmail.com   25      4      1
# 5         2    bob@gmail.com   25      1      0
# 6         3  carol@gmail.com   30      2      0
# 7         3  carol@gmail.com   30      1      0
# 8         3  carol@gmail.com   30      3      0
# 9         3  carol@gmail.com   30      4      0
# 10        3  carol@gmail.com   30      5      1

# %%
m = t1.merge(t2, on='user_id')
m
# Out:
#     user_id            email  age  ad_id  click
# 0         1  alice@gmail.com   20      1      1
# 1         1  alice@gmail.com   20      2      0
# 2         1  alice@gmail.com   20      5      0
# 3         2    bob@gmail.com   25      3      0
# 4         2    bob@gmail.com   25      4      1
# 5         2    bob@gmail.com   25      1      0
# 6         3  carol@gmail.com   30      2      0
# 7         3  carol@gmail.com   30      1      0
# 8         3  carol@gmail.com   30      3      0
# 9         3  carol@gmail.com   30      4      0
# 10        3  carol@gmail.com   30      5      1
